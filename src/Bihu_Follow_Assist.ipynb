# %%
# coding: utf-8
from urllib import request, parse
import ssl
import json
import time

# 关注流程
# 1、遍历热门中的文章列表；
# 2、如果未关注，查看当前收益是否达到moneyCondition，如果达到这关注；
# 3、继续循环，直到没有

# 优点
# 关注到的，都是写文章的，并目前收益还不错的。

# 配置变量
config = {
    # 用户ID
    'userId':'',  # TODO, 你的用户id，PC上在币乎页面，按F12，network页面找到对应的请求，可以找到
    # 登录token
    'accessToken':'', # TODO, 你的token，登录后币乎服务器返回，获取方法与userId相同。
    # 收益，收益多于多少时关注
    'moneyCondition':100 # 可以根据你的实际情况设置阈值条件
}

def datetime_str():  
    format = '%Y-%m-%d %H:%M:%S'
    value = time.localtime(time.time())
    dt = time.strftime(format,value)  
    return dt

# 打印日志信息
def print_info(info):
    log = "[%s]--%s" % (datetime_str(), info)
    print(log)

# 关注某人 
# https://be02.bihu.com/bihube-pc/api/content/follow
def Follow(subjectUserId, userName):
    print_info("正在关注【%s】..." % (userName))
    url = r'https://be02.bihu.com/bihube-pc/api/content/follow'
    headers = {
        'User-Agent': r'Mozilla/5.0 (Windows NT 10.0; Win64; x64)',
        'Content-Type': r'application/x-www-form-urlencoded;charset=utf-8',
        'Referer': r'https://bihu.com/people/' + subjectUserId,
        'Connection': 'keep-alive',
        'Accept-Encoding': 'gzip, deflate, br',
        'Accept-Language': 'zh-CN,zh;q=0.9'
    }
    
    data = {
        'userId': config['userId'],
        'accessToken': config['accessToken'],
        'subjectUserId': subjectUserId
    }
    context = ssl._create_unverified_context()
    data = parse.urlencode(data).encode('utf-8')
    req = request.Request(url, headers=headers, data=data)

    rsp = ""
    try:
        rsp = request.urlopen(req, context = context).read()
        rsp = rsp.decode('utf-8')
    except e:
        print_info(str(e.code) + '\r\n' + e.reason);

    print_info("关注【%s】返回：%s" % (userName, rsp))

    return rsp

# 获取热门文章列表，code为板块的名字，pageNum为页序
# 如果code为空，这Referer为https://bihu.com/?category=recommend
# 如果code不为空，则Referer为https://bihu.com/?category=hots&code=BTC
def getHotArtList(pageNum = 1, code = ''):
    print_info("查询第【" + str(pageNum) + "】页热门文章" )
    url = r'https://be02.bihu.com/bihube-pc/api/content/show/hotArtList'
    
    # 去掉空格
    code = code.strip()
    
    # Referer头默认为热门页面
    referer = r'https://bihu.com/?category=recommend' 
    if code =="":
        referer = r'https://bihu.com/?category=hots&code=' + code
    
    # 组装头信息
    headers = {
        'User-Agent': r'Mozilla/5.0 (Windows NT 10.0; Win64; x64)',
        'Content-Type': r'application/x-www-form-urlencoded;charset=utf-8',
        'Referer': referer,
        'Connection': 'keep-alive',
        'Accept-Encoding': 'gzip, deflate, br',
        'Accept-Language': 'zh-CN,zh;q=0.9'
    }
    
    data = {
        'userId': config['userId'],
        'accessToken': config['accessToken'],
        'pageNum': pageNum
    }
    
    if len(code) != 0:
        data['code'] = code
    
    context = ssl._create_unverified_context()
    data = parse.urlencode(data).encode('utf-8')
    req = request.Request(url, headers=headers, data=data)
    
    rsp = ""
    try:
        rsp = request.urlopen(req, context = context).read()
        rsp = rsp.decode('utf-8')
    except urllib2.URLError as e:
        print_info(str(e.code) + '\r\n' + e.reason);

    # print_info(rsp)
    return rsp

def parseHotArtList(body):
    data_str = json.loads(body);
    res = data_str['res'];

    # 请求是否成功
    is_succ = False;
    pages = 0;
    log_content_format = '【%s】的文章，点赞量：%d，收益:%s，加为关注 :)'
    if res == 1 and data_str["data"]["size"] > 0:
        pages = data_str["data"]["pages"]
        # 遍历关注对象
        for item in data_str["data"]["list"]:
            if item["follow"] == 0 \
            and item["money"] >= config['moneyCondition']:
                log_content = log_content_format % (item['userName'], item["ups"], item["money"])
                print_info(log_content)
                # 热门里面，如果未关注，且收益大于设定值，关注
                Follow(item["userId"],item['userName'])
                time.sleep(0.5)
    
    if res == 1:
        is_succ  = True;

    return is_succ, pages

def Run():
    # 第一次获取，为了拿到页数，好做循环
    pageIndex = 0
    pages = 1
    is_suc = True
 
    while is_suc and pageIndex < pages:
        pageIndex += 1
        time.sleep(1)
        body = getHotArtList(pageIndex)
        is_suc, pages = parseHotArtList(body)
        
		# 请求太频繁时，进入下面等待，一分钟检测一次
        while (not is_suc):
            print_info(body)
            print_info("60秒后请稍后重试")
            time.sleep(60)
            body = getHotArtList(pageIndex)
            is_suc, pages = parseHotArtList(body)
          
Run()
print_info("程序已退出")
# Out:
# [2018-04-19 09:22:25]--查询第【1】页热门文章
# [2018-04-19 09:22:25]--【wdctll】的文章，点赞量：916，收益:2696.19，加为关注 :)
# [2018-04-19 09:22:25]--正在关注【wdctll】...
# [2018-04-19 09:22:25]--关注【wdctll】返回：{"data":null,"res":1,"resMsg":"success"}
# [2018-04-19 09:22:26]--【JIMI】的文章，点赞量：3692，收益:7330.84，加为关注 :)
# [2018-04-19 09:22:26]--正在关注【JIMI】...
# [2018-04-19 09:22:26]--关注【JIMI】返回：{"data":null,"res":1,"resMsg":"success"}
# [2018-04-19 09:22:26]--【玩火的猴子】的文章，点赞量：3157，收益:5857.28，加为关注 :)
# [2018-04-19 09:22:26]--正在关注【玩火的猴子】...
# [2018-04-19 09:22:27]--关注【玩火的猴子】返回：{"data":null,"res":1,"resMsg":"success"}
# [2018-04-19 09:22:27]--【南宫远】的文章，点赞量：2472，收益:3895.08，加为关注 :)
# [2018-04-19 09:22:27]--正在关注【南宫远】...
# [2018-04-19 09:22:27]--关注【南宫远】返回：{"data":null,"res":1,"resMsg":"success"}
# [2018-04-19 09:22:28]--【付宰飞_区块链修行录】的文章，点赞量：2923，收益:5139.76，加为关注 :)
# [2018-04-19 09:22:28]--正在关注【付宰飞_区块链修行录】...
# [2018-04-19 09:22:28]--关注【付宰飞_区块链修行录】返回：{"data":null,"res":1,"resMsg":"success"}
# [2018-04-19 09:22:28]--【湘乡的大树】的文章，点赞量：3768，收益:6679.78，加为关注 :)
# [2018-04-19 09:22:28]--正在关注【湘乡的大树】...
# [2018-04-19 09:22:29]--关注【湘乡的大树】返回：{"data":null,"res":1,"resMsg":"success"}
# [2018-04-19 09:22:29]--【吴庆英】的文章，点赞量：2811，收益:4745，加为关注 :)
# [2018-04-19 09:22:29]--正在关注【吴庆英】...
# [2018-04-19 09:22:29]--关注【吴庆英】返回：{"data":null,"res":1,"resMsg":"success"}
# [2018-04-19 09:22:30]--【孤独的异客】的文章，点赞量：1704，收益:2617.87，加为关注 :)
# [2018-04-19 09:22:30]--正在关注【孤独的异客】...
# [2018-04-19 09:22:30]--关注【孤独的异客】返回：{"data":null,"res":1,"resMsg":"success"}
# [2018-04-19 09:22:31]--【圊呓语】的文章，点赞量：3523，收益:5522.54，加为关注 :)
# [2018-04-19 09:22:31]--正在关注【圊呓语】...
# [2018-04-19 09:22:31]--关注【圊呓语】返回：{"data":null,"res":1,"resMsg":"success"}
# [2018-04-19 09:22:31]--【林星辰】的文章，点赞量：185，收益:803.22，加为关注 :)
# [2018-04-19 09:22:31]--正在关注【林星辰】...
# [2018-04-19 09:22:32]--关注【林星辰】返回：{"data":null,"res":1,"resMsg":"success"}
# [2018-04-19 09:22:32]--【荆凯shuke037】的文章，点赞量：667，收益:1125.15，加为关注 :)
# [2018-04-19 09:22:32]--正在关注【荆凯shuke037】...
# [2018-04-19 09:22:32]--关注【荆凯shuke037】返回：{"data":null,"res":1,"resMsg":"success"}
# [2018-04-19 09:22:33]--【区块链生存指南】的文章，点赞量：2483，收益:3605.09，加为关注 :)
# [2018-04-19 09:22:33]--正在关注【区块链生存指南】...
# [2018-04-19 09:22:33]--关注【区块链生存指南】返回：{"data":null,"res":1,"resMsg":"success"}
# [2018-04-19 09:22:33]--【北平魏少】的文章，点赞量：2792，收益:3489.28，加为关注 :)
# [2018-04-19 09:22:33]--正在关注【北平魏少】...
# [2018-04-19 09:22:34]--关注【北平魏少】返回：{"data":null,"res":1,"resMsg":"success"}
# [2018-04-19 09:22:34]--【oleole九日笔记】的文章，点赞量：1901，收益:2161.56，加为关注 :)
# [2018-04-19 09:22:34]--正在关注【oleole九日笔记】...
# [2018-04-19 09:22:34]--关注【oleole九日笔记】返回：{"data":null,"res":1,"resMsg":"success"}
# [2018-04-19 09:22:35]--【马小惠】的文章，点赞量：370，收益:580.54，加为关注 :)
# [2018-04-19 09:22:35]--正在关注【马小惠】...
# [2018-04-19 09:22:35]--关注【马小惠】返回：{"data":null,"res":1,"resMsg":"success"}
# [2018-04-19 09:22:36]--【区块链趋势狂人】的文章，点赞量：2248，收益:2517.71，加为关注 :)
# [2018-04-19 09:22:36]--正在关注【区块链趋势狂人】...
# [2018-04-19 09:22:36]--关注【区块链趋势狂人】返回：{"data":null,"res":1,"resMsg":"success"}
# [2018-04-19 09:22:36]--【AlphaBo】的文章，点赞量：806，收益:1005.64，加为关注 :)
# [2018-04-19 09:22:36]--正在关注【AlphaBo】...
# [2018-04-19 09:22:36]--关注【AlphaBo】返回：{"data":null,"res":1,"resMsg":"success"}
# [2018-04-19 09:22:37]--【币云天】的文章，点赞量：255，收益:320.15，加为关注 :)
# [2018-04-19 09:22:37]--正在关注【币云天】...
# [2018-04-19 09:22:37]--关注【币云天】返回：{"data":null,"res":1,"resMsg":"success"}
# [2018-04-19 09:22:38]--【付宰飞_区块链修行录】的文章，点赞量：889，收益:903.84，加为关注 :)
# [2018-04-19 09:22:38]--正在关注【付宰飞_区块链修行录】...
# [2018-04-19 09:22:38]--关注【付宰飞_区块链修行录】返回：{"data":null,"res":0,"resMsg":"已关注此用户。"}
# [2018-04-19 09:22:39]--查询第【2】页热门文章
# [2018-04-19 09:22:40]--【小韭菜的逆袭】的文章，点赞量：1922，收益:1835.16，加为关注 :)
# [2018-04-19 09:22:40]--正在关注【小韭菜的逆袭】...
# [2018-04-19 09:22:40]--关注【小韭菜的逆袭】返回：{"data":null,"res":1,"resMsg":"success"}
# [2018-04-19 09:22:40]--【Tesla】的文章，点赞量：2112，收益:2083.26，加为关注 :)
# [2018-04-19 09:22:40]--正在关注【Tesla】...
# [2018-04-19 09:22:41]--关注【Tesla】返回：{"data":null,"res":1,"resMsg":"success"}
# [2018-04-19 09:22:41]--【松果】的文章，点赞量：599，收益:682.88，加为关注 :)
# [2018-04-19 09:22:41]--正在关注【松果】...
# [2018-04-19 09:22:41]--关注【松果】返回：{"data":null,"res":1,"resMsg":"success"}
# [2018-04-19 09:22:42]--【江湖小郎中】的文章，点赞量：50，收益:238.23，加为关注 :)
# [2018-04-19 09:22:42]--正在关注【江湖小郎中】...
# [2018-04-19 09:22:42]--关注【江湖小郎中】返回：{"data":null,"res":1,"resMsg":"success"}
# [2018-04-19 09:22:42]--【币乎日旦评】的文章，点赞量：1467，收益:1436.33，加为关注 :)
# [2018-04-19 09:22:42]--正在关注【币乎日旦评】...
# [2018-04-19 09:22:43]--关注【币乎日旦评】返回：{"data":null,"res":1,"resMsg":"success"}
# [2018-04-19 09:22:43]--【区块链每日必读】的文章，点赞量：649，收益:638.64，加为关注 :)
# [2018-04-19 09:22:43]--正在关注【区块链每日必读】...
# [2018-04-19 09:22:43]--关注【区块链每日必读】返回：{"data":null,"res":1,"resMsg":"success"}
# [2018-04-19 09:22:44]--【赋能懂事局局长】的文章，点赞量：1077，收益:1052.97，加为关注 :)
# [2018-04-19 09:22:44]--正在关注【赋能懂事局局长】...
# [2018-04-19 09:22:44]--关注【赋能懂事局局长】返回：{"data":null,"res":1,"resMsg":"success"}
# [2018-04-19 09:22:45]--【闪电】的文章，点赞量：155，收益:238.19，加为关注 :)
# [2018-04-19 09:22:45]--正在关注【闪电】...
# [2018-04-19 09:22:45]--关注【闪电】返回：{"data":null,"res":1,"resMsg":"success"}
# [2018-04-19 09:22:45]--【萝卜泥区块链测评】的文章，点赞量：1337，收益:1265.41，加为关注 :)
# [2018-04-19 09:22:45]--正在关注【萝卜泥区块链测评】...
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-10-556a8fd2ddff> in Follow(subjectUserId, userName)
#      61         rsp = request.urlopen(req, context = context).read()
# ---> 62         rsp = rsp.decode('utf-8')
#      63     except e:
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0x8b in position 1: invalid start byte
#
# During handling of the above exception, another exception occurred:
#
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-556a8fd2ddff> in <module>()
#     160             is_suc, pages = parseHotArtList(body)
#     161
# --> 162 Run()
#     163 print_info("程序已退出")
#
# <ipython-input-10-556a8fd2ddff> in Run()
#     150         time.sleep(1)
#     151         body = getHotArtList(pageIndex)
# --> 152         is_suc, pages = parseHotArtList(body)
#     153
#     154                 # 请求太频繁时，进入下面等待，一分钟检测一次
#
# <ipython-input-10-556a8fd2ddff> in parseHotArtList(body)
#     132                 print_info(log_content)
#     133                 # 热门里面，如果未关注，且收益大于设定值，关注
# --> 134                 Follow(item["userId"],item['userName'])
#     135                 time.sleep(0.5)
#     136
#
# <ipython-input-10-556a8fd2ddff> in Follow(subjectUserId, userName)
#      61         rsp = request.urlopen(req, context = context).read()
#      62         rsp = rsp.decode('utf-8')
# ---> 63     except e:
#      64         print_info(str(e.code) + '\r\n' + e.reason);
#      65
#
# NameError: name 'e' is not defined
